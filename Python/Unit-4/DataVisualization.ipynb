# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepsphere-AI/DataAnalyticsTraining/blob/main/Python/Unit-4/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##############################
# Unit # 4
# Data Visualization.
#
##############################
import matplotlib.pyplot as plt
import numpy as np # For Data, not Data Visual
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints) # Presenting the data in the chart
plt.show() # Display the chart

# %%
##
## Matplotlib Line
## Line graphs are better to use than bar graphs.
## Line graphs can also be used to compare changes over the same period of time for more than one group.
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
#plt.plot(ypoints, linestyle = 'dotted')
plt.plot(ypoints, linestyle = 'dashed',color = 'r',linewidth = '5.5')
plt.show()

# %%
##
## Multiple Lines
##
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
##
## Multiple Lines
##

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'green','size':20}

plt.title("Sports Watch Data", fontdict = font2,loc = 'center')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#
# The hist() function will read the array and produce a histogram:
# Ex:  Patient Age Group  - Histogram shows the distribution of the data.
#     2 people from 40 - 50 Age Group
#     5 people from 50 - 60 Age Group
#     15 people from 60 - 70 Age Group
#     31 people from 70 - 80 Age Group
#
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(190, 10, 250)

plt.hist(x)
plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# Pie Chart
# Start Angle
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
# The startangle parameter is defined with an angle in degrees, default angle is 0:
# Example: Customer Segmentation
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors=mycolors,startangle = 90) # Start the first wedge at 90 degrees:
plt.legend(title = "Fruits Distribution")
plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# Bars
# Bar charts enable us to compare numerical values like integers and percentages.
# They use the length of each bar to represent the value of each variable.
# For example, bar charts show variations in categories or
# subcategories scaling width or height across simple, spaced bars, or rectangles.
# Ex:  Customer Segmentaion,
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color = "g",width = 1.0)
plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# Scatter
# Form: Is the association linear or nonlinear? # Stock Market Prediction, Patient Behavior
# Direction: Is the association positive or negative?
# Strength: Does the association appear to be strong, moderately strong, or weak?
# Outliers: Do there appear to be any data points that are unusually far away from the general pattern?
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

import matplotlib.pyplot as plt
import numpy as np

#Sample #1
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

#plt.scatter(x, y, s=sizes)
#plt.scatter(x, y,c=colors,cmap='viridis')
#plt.colorbar()

#Sample #2
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.scatter(x, y,color = '#88c999')

plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# First Seaborn Line Plot
# Seaborn is a Python data visualization library based on matplotlib
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
## Seaborn helps you explore and understand your data through a wide range of functions,
## plot styles, and layouts. It also has data sets that would be very useful for both beginners and experts,
## its active community program will also help you improve your data and effectively convey the message.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Year = [2012, 2014, 2016, 2020, 2021, 2022, 2018]
Profit = [80, 75.8, 74, 65, 99.5, 19, 33.6]
##
## In the below line-plot, linear relationship between the two data variables – ‘Year’ and ‘Profit’.
##

data_plot = pd.DataFrame({"Year":Year, "Profit":Profit})
sns.lineplot(x = "Year", y = "Profit", data=data_plot)
plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# II Seaborn Create bar plot
# # Create bar plot
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")
sns.barplot(x="class", y="survived", hue="sex", data=titanic) # Create bar plot
plt.show()

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# III Create heatmap
# # Create heatmap
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
import matplotlib.pyplot as plt
flights = sns.load_dataset("flights")
flights = flights.pivot("month","year", "passengers")
sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu") # Create heatmap
plt.show()
# Out:
# <ipython-input-11-be329340bedd>:8: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month","year", "passengers")

# %% [markdown]
# **Advantages of using Seaborn**
#
# 1. Extensive Gallery of examples:
# 2. Active community and documentation:
# 3. Flexibility and customization:
# 4. Ease of use:
# 5. Built-in statistical functionality:
# 6. Cross-platform compatibility:
# 7. Continuous development and updates:
# 8. Integration with other libraries:
# 9. Support for both complex and basic plots:
#
# ***Tips for Effective Visualization***
#
# 1. Understand your data:
# 2. Choose the right plot type:
# 3. Keep it simple:
# 4. Use color purposefully:
# 5. Provide context and annotations:
# 6. Experiment and iterate:
# 7. Seek feedback:
